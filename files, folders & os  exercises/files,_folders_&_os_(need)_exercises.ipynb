# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Files, Folders & OS (Need) Exercises</span></div>

# %% [markdown]
# ## Task 1

# %%
dictionary = {
    'jan': '01', 'feb': '02', 'mar': '03',
    'apr': '04', 'may': '05', 'jun': '06',
    'jul': '07', 'aug': '08', 'sep': '09',
    'oct': '10', 'nov': '11', 'dec': '12'
}
file_name = 'oct-08_singapore.txt'
split_list = file_name.split("_")
date = split_list[0]
country = split_list[1]
split_date = date.split("-")
month = split_date[0]
day = split_date[1]
number_month = dictionary[month]
new_file_name = f"{number_month}-{day}-{country}"
print(new_file_name)
# Out:
# 10-08-singapore.txt

# %% [markdown]
# ## Task 2

# %%
def rename_my_file(old_file_name):
    split_list = old_file_name.split("_")
    date = split_list[0]
    country = split_list[1]
    split_date = date.split("-")
    month = split_date[0]
    day = split_date[1]
    number_month = dictionary[month]
    new_file_name = f"{number_month}-{day}-{country}"
    return new_file_name

rename_my_file("sep-01_Singapore.txt")
# Out:
# '09-01-Singapore.txt'

# %% [markdown]
# ## Task 3

# %%
file_list =['oct-08_singapore.txt', 'jul-10_cairo.txt', 'may-15_dhaka.txt',
 'may-13_cairo.txt', 'oct-21_cairo.txt', 'jan-10_singapore.txt',
 'jun-20_tokyo.txt', 'aug-06_jakarta.txt', 'dec-21_karachi.txt',
 'jan-01_tokyo.txt']
for old_file_name in file_list:
    new_file_name = rename_my_file(old_file_name)
    print(f"{old_file_name} ----> {new_file_name}")
# Out:
# oct-08_singapore.txt ----> 10-08-singapore.txt
# jul-10_cairo.txt ----> 07-10-cairo.txt
# may-15_dhaka.txt ----> 05-15-dhaka.txt
# may-13_cairo.txt ----> 05-13-cairo.txt
# oct-21_cairo.txt ----> 10-21-cairo.txt
# jan-10_singapore.txt ----> 01-10-singapore.txt
# jun-20_tokyo.txt ----> 06-20-tokyo.txt
# aug-06_jakarta.txt ----> 08-06-jakarta.txt
# dec-21_karachi.txt ----> 12-21-karachi.txt
# jan-01_tokyo.txt ----> 01-01-tokyo.txt

# %% [markdown]
# ## Task 4

# %%
import glob
import os
import shutil
all_txt_files = glob.glob("os-collaboration-exercise-data/**/*.txt", recursive=True)
for full_path in all_txt_files:
    try:
        old_file_name = full_path.split(os.path.sep)[-1]
        new_file_name = rename_my_file(old_file_name)
        new_path = os.path.join('os-collaboration-exercise-data', new_file_name)
        os.rename(full_path, new_path)
        print(f"successful moving of: {new_file_name}")
    except FileExistsError:
        print(f"Folder already Added: {path}")
# Out:
# successful moving of: 04-01-melbourne.txt
# successful moving of: 04-01-shanghai.txt
# successful moving of: 04-01-singapore.txt
# successful moving of: 04-02-cairo.txt
# successful moving of: 04-02-jakarta.txt
# successful moving of: 04-02-karachi.txt
# successful moving of: 04-02-shanghai.txt
# successful moving of: 04-03-manila.txt
# successful moving of: 04-03-osaka.txt
# successful moving of: 04-03-singapore.txt
# successful moving of: 04-03-tokyo.txt
# successful moving of: 04-04-manila.txt
# successful moving of: 04-04-melbourne.txt
# successful moving of: 04-04-shanghai.txt
# successful moving of: 04-04-singapore.txt
# successful moving of: 04-05-karachi.txt
# successful moving of: 04-05-melbourne.txt
# successful moving of: 04-05-shanghai.txt
# successful moving of: 04-05-singapore.txt
# successful moving of: 04-06-cairo.txt
# successful moving of: 04-06-jakarta.txt
# successful moving of: 04-06-karachi.txt
# successful moving of: 04-06-manila.txt
# ...

# %% [markdown]
# ## Task 5

# %%
country_list = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
                'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']
for country in country_list:
    folder_path = os.path.join("countries", country)
    os.mkdir(folder_path)
    print(f"{country} folder successfully created")
# Out:
# Cairo folder successfully created
# Dhaka folder successfully created
# Jakarta folder successfully created
# Karachi folder successfully created
# Manila folder successfully created
# Melbourne folder successfully created
# Osaka folder successfully created
# Shanghai folder successfully created
# Singapore folder successfully created
# Tokyo folder successfully created

# %% [markdown]
# ## Task 6

# %%
cairo_files = glob.glob("os-collaboration-exercise-data/**/*cairo.txt", recursive=True)
for country_file_path in cairo_files:
    new_file_path = os.path.join("countries", "Cairo")
    shutil.move(country_file_path, new_file_path)
    print(f"Transferred to {new_file_path}")
# Out:
# Transferred to countries\Cairo
# Transferred to countries\Cairo
# Transferred to countries\Cairo
# Transferred to countries\Cairo
# Transferred to countries\Cairo
# Transferred to countries\Cairo
# Transferred to countries\Cairo
# Transferred to countries\Cairo
# Transferred to countries\Cairo
# Transferred to countries\Cairo
# Transferred to countries\Cairo
# Transferred to countries\Cairo
# Transferred to countries\Cairo
# Transferred to countries\Cairo
# Transferred to countries\Cairo
# Transferred to countries\Cairo
# Transferred to countries\Cairo
# Transferred to countries\Cairo
# Transferred to countries\Cairo
# Transferred to countries\Cairo
# Transferred to countries\Cairo
# Transferred to countries\Cairo
# Transferred to countries\Cairo
# Transferred to countries\Cairo
# Transferred to countries\Cairo
# Transferred to countries\Cairo
# Transferred to countries\Cairo
# Transferred to countries\Cairo
# Transferred to countries\Cairo
# Transferred to countries\Cairo
# ...

# %% [markdown]
# ## Task 7

# %%
country_list = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
                'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']
for country in country_list:
    country_files = glob.glob(f"os-collaboration-exercise-data/**/*{country}.txt", recursive=True)
    for country_file_path in country_files:
        new_file_path = os.path.join("countries", country)
        shutil.move(country_file_path, new_file_path)
        print(f"Transferred to {new_file_path}")
# Out:
# Transferred to countries\Dhaka
# Transferred to countries\Dhaka
# Transferred to countries\Dhaka
# Transferred to countries\Dhaka
# Transferred to countries\Dhaka
# Transferred to countries\Dhaka
# Transferred to countries\Dhaka
# Transferred to countries\Dhaka
# Transferred to countries\Dhaka
# Transferred to countries\Dhaka
# Transferred to countries\Dhaka
# Transferred to countries\Dhaka
# Transferred to countries\Dhaka
# Transferred to countries\Dhaka
# Transferred to countries\Dhaka
# Transferred to countries\Dhaka
# Transferred to countries\Dhaka
# Transferred to countries\Dhaka
# Transferred to countries\Dhaka
# Transferred to countries\Dhaka
# Transferred to countries\Dhaka
# Transferred to countries\Dhaka
# Transferred to countries\Dhaka
# Transferred to countries\Dhaka
# Transferred to countries\Dhaka
# Transferred to countries\Dhaka
# Transferred to countries\Dhaka
# Transferred to countries\Dhaka
# Transferred to countries\Dhaka
# Transferred to countries\Dhaka
# ...
